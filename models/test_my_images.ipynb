# %%
from pathlib import Path
import PIL
import matplotlib.pyplot as plt
import numpy as np
import joblib

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

# %%
clf = joblib.load('./objects/knn.pkl')
my_images = Path('../my_images/processed')
white = list(my_images.glob('White/*'))
basmati = list(my_images.glob('Basmati/*'))
jasmine = list(my_images.glob('Jasmine/*'))
arborio = list(my_images.glob('Arborio/*'))

# %%
for index, path in enumerate(white):
    with PIL.Image.open(str(path)).convert('L') as img:
        raw_image = np.array([np.array(img.getdata()).flatten()])
        prediction = clf.predict(raw_image)
        name = str(path).split('/')[-1]
        print(f'{name} predicted as \t{prediction}')
# Out:
# White (1).jpg predicted as 	['Jasmine']
# White (2).jpg predicted as 	['Arborio']
# White (3).jpg predicted as 	['Jasmine']
# White (4).jpg predicted as 	['Jasmine']
# White (5).jpg predicted as 	['Jasmine']
# White (6).jpg predicted as 	['Jasmine']
# White (7).jpg predicted as 	['Arborio']
# White (8).jpg predicted as 	['Arborio']
# White (9).jpg predicted as 	['Jasmine']
# White (10).jpg predicted as 	['Arborio']
# White (11).jpg predicted as 	['Arborio']
# White (12).jpg predicted as 	['Arborio']

# %% [markdown]
# That is expected since I tested on some generic white rice and not a particular type of rice.

# %%
for index, path in enumerate(basmati):
    with PIL.Image.open(str(path)).convert('L') as img:
        raw_image = np.array([np.array(img.getdata()).flatten()])
        prediction = clf.predict(raw_image)
        name = str(path).split('/')[-1]
        print(f'{name} predicted as \t{prediction}')
# Out:
# Basmati (1).jpg predicted as 	['Arborio']
# Basmati (2).jpg predicted as 	['Arborio']
# Basmati (3).jpg predicted as 	['Arborio']
# Basmati (4).jpg predicted as 	['Arborio']
# Basmati (5).jpg predicted as 	['Arborio']
# Basmati (6).jpg predicted as 	['Arborio']
# Basmati (7).jpg predicted as 	['Arborio']
# Basmati (8).jpg predicted as 	['Arborio']
# Basmati (9).jpg predicted as 	['Arborio']
# Basmati (10).jpg predicted as 	['Jasmine']
# Basmati (11).jpg predicted as 	['Arborio']
# Basmati (12).jpg predicted as 	['Jasmine']
# Basmati (13).jpg predicted as 	['Jasmine']
# Basmati (14).jpg predicted as 	['Jasmine']
# Basmati (15).jpg predicted as 	['Jasmine']
# Basmati (16).jpg predicted as 	['Jasmine']
# Basmati (17).jpg predicted as 	['Jasmine']
# Basmati (18).jpg predicted as 	['Jasmine']
# Basmati (19).jpg predicted as 	['Jasmine']
# Basmati (20).jpg predicted as 	['Jasmine']
# Basmati (21).jpg predicted as 	['Basmati']
# Basmati (22).jpg predicted as 	['Arborio']
# Basmati (23).jpg predicted as 	['Jasmine']
# Basmati (24).jpg predicted as 	['Jasmine']
# Basmati (25).jpg predicted as 	['Jasmine']
# Basmati (26).jpg predicted as 	['Basmati']
# Basmati (27).jpg predicted as 	['Basmati']
# Basmati (28).jpg predicted as 	['Jasmine']
# Basmati (29).jpg predicted as 	['Arborio']
# Basmati (30).jpg predicted as 	['Basmati']
# Basmati (31).jpg predicted as 	['Jasmine']
# Basmati (32).jpg predicted as 	['Jasmine']
# Basmati (33).jpg predicted as 	['Jasmine']
# Basmati (34).jpg predicted as 	['Jasmine']
# Basmati (35).jpg predicted as 	['Jasmine']
# Basmati (36).jpg predicted as 	['Jasmine']
# Basmati (37).jpg predicted as 	['Jasmine']
# Basmati (38).jpg predicted as 	['Jasmine']
# Basmati (39).jpg predicted as 	['Arborio']
# Basmati (40).jpg predicted as 	['Jasmine']
# Basmati (41).jpg predicted as 	['Jasmine']

# %% [markdown]
# What I can notice is that the model tends to predict shorter grains as Arborio and longer grains as Jasmine. It only predicts the last two images as Basmati.

# %%
for index, path in enumerate(jasmine):
    with PIL.Image.open(str(path)).convert('L') as img:
        raw_image = np.array([np.array(img.getdata()).flatten()])
        prediction = clf.predict(raw_image)
        name = str(path).split('/')[-1]
        print(f'{name} predicted as \t{prediction}')
# Out:
# Jasmine (1).jpg predicted as 	['Jasmine']
# Jasmine (2).jpg predicted as 	['Jasmine']
# Jasmine (3).jpg predicted as 	['Basmati']
# Jasmine (4).jpg predicted as 	['Jasmine']
# Jasmine (5).jpg predicted as 	['Jasmine']
# Jasmine (6).jpg predicted as 	['Jasmine']
# Jasmine (7).jpg predicted as 	['Basmati']
# Jasmine (8).jpg predicted as 	['Arborio']
# Jasmine (9).jpg predicted as 	['Jasmine']
# Jasmine (10).jpg predicted as 	['Arborio']
# Jasmine (11).jpg predicted as 	['Basmati']
# Jasmine (12).jpg predicted as 	['Basmati']
# Jasmine (13).jpg predicted as 	['Arborio']
# Jasmine (14).jpg predicted as 	['Basmati']
# Jasmine (15).jpg predicted as 	['Basmati']
# Jasmine (16).jpg predicted as 	['Basmati']
# Jasmine (17).jpg predicted as 	['Basmati']
# Jasmine (18).jpg predicted as 	['Basmati']
# Jasmine (19).jpg predicted as 	['Basmati']
# Jasmine (20).jpg predicted as 	['Basmati']
# Jasmine (21).jpg predicted as 	['Basmati']
# Jasmine (22).jpg predicted as 	['Basmati']
# Jasmine (23).jpg predicted as 	['Arborio']
# Jasmine (24).jpg predicted as 	['Basmati']
# Jasmine (25).jpg predicted as 	['Basmati']
# Jasmine (26).jpg predicted as 	['Arborio']
# Jasmine (27).jpg predicted as 	['Basmati']
# Jasmine (28).jpg predicted as 	['Arborio']
# Jasmine (29).jpg predicted as 	['Basmati']

# %%
for index, path in enumerate(arborio):
    with PIL.Image.open(str(path)).convert('L') as img:
        raw_image = np.array([np.array(img.getdata()).flatten()])
        prediction = clf.predict(raw_image)
        name = str(path).split('/')[-1]
        print(f'{name} predicted as \t{prediction}')
# Out:
# Arborio (1).jpg predicted as 	['Arborio']
# Arborio (2).jpg predicted as 	['Arborio']
# Arborio (3).jpg predicted as 	['Arborio']
# Arborio (4).jpg predicted as 	['Ipsala']
# Arborio (5).jpg predicted as 	['Arborio']
# Arborio (6).jpg predicted as 	['Ipsala']
# Arborio (7).jpg predicted as 	['Arborio']
# Arborio (8).jpg predicted as 	['Arborio']
# Arborio (9).jpg predicted as 	['Arborio']
# Arborio (10).jpg predicted as 	['Arborio']
# Arborio (11).jpg predicted as 	['Arborio']
# Arborio (12).jpg predicted as 	['Arborio']
# Arborio (13).jpg predicted as 	['Arborio']
# Arborio (14).jpg predicted as 	['Arborio']
# Arborio (15).jpg predicted as 	['Basmati']
# Arborio (16).jpg predicted as 	['Arborio']
# Arborio (17).jpg predicted as 	['Arborio']
# Arborio (18).jpg predicted as 	['Arborio']
# Arborio (19).jpg predicted as 	['Arborio']
# Arborio (20).jpg predicted as 	['Arborio']
# Arborio (21).jpg predicted as 	['Arborio']
# Arborio (22).jpg predicted as 	['Ipsala']
# Arborio (23).jpg predicted as 	['Arborio']
# Arborio (24).jpg predicted as 	['Ipsala']
# Arborio (25).jpg predicted as 	['Arborio']
# Arborio (26).jpg predicted as 	['Arborio']
# Arborio (27).jpg predicted as 	['Arborio']
# Arborio (28).jpg predicted as 	['Arborio']
# Arborio (29).jpg predicted as 	['Arborio']
# Arborio (30).jpg predicted as 	['Arborio']
# Arborio (31).jpg predicted as 	['Ipsala']
# Arborio (32).jpg predicted as 	['Arborio']
# Arborio (33).jpg predicted as 	['Arborio']
# Arborio (34).jpg predicted as 	['Arborio']
# Arborio (35).jpg predicted as 	['Arborio']
# Arborio (36).jpg predicted as 	['Arborio']
# Arborio (37).jpg predicted as 	['Basmati']
# Arborio (38).jpg predicted as 	['Arborio']
# Arborio (39).jpg predicted as 	['Arborio']
# Arborio (40).jpg predicted as 	['Ipsala']
# Arborio (41).jpg predicted as 	['Arborio']
# Arborio (42).jpg predicted as 	['Arborio']
# Arborio (43).jpg predicted as 	['Ipsala']
# Arborio (44).jpg predicted as 	['Arborio']
# Arborio (45).jpg predicted as 	['Arborio']
# Arborio (46).jpg predicted as 	['Arborio']
# Arborio (47).jpg predicted as 	['Arborio']

# %%
raw_images = []
labels = []

for path in arborio + basmati + jasmine:
    with PIL.Image.open(str(path)).convert('L') as img:
        raw_image = np.array(img.getdata()).flatten()
        label = str(path).split('/')[3]
        raw_images.append(raw_image)
        labels.append(label)

X = np.array(raw_images)
y = np.array(labels)

# %%
print('KNN')
clf = joblib.load('./objects/knn.pkl')
y_pred = clf.predict(X)
print(f'Accuracy: {accuracy_score(y, y_pred)}')
disp = ConfusionMatrixDisplay.from_predictions(y, y_pred, labels=clf.classes_)
# Out:
# KNN
# Accuracy: 0.41025641025641024

# %%
print('SVM')
clf = joblib.load('./objects/svm.pkl')
y_pred = clf.predict(X)
print(f'Accuracy: {accuracy_score(y, y_pred)}')
disp = ConfusionMatrixDisplay.from_predictions(y, y_pred, labels=clf.classes_)
# Out:
# SVM
# Accuracy: 0.27350427350427353

# %%
print('Perceptron')
clf = joblib.load('./objects/perceptron.pkl')
y_pred = clf.predict(X)
print(f'Accuracy: {accuracy_score(y, y_pred)}')
disp = ConfusionMatrixDisplay.from_predictions(y, y_pred, labels=clf.classes_)
# Out:
# Perceptron
# Accuracy: 0.38461538461538464

# %%
print('Log loss')
clf = joblib.load('./objects/log_loss.pkl')
y_pred = clf.predict(X)
print(f'Accuracy: {accuracy_score(y, y_pred)}')
disp = ConfusionMatrixDisplay.from_predictions(y, y_pred, labels=clf.classes_)
# Out:
# Log loss
# Accuracy: 0.2222222222222222
